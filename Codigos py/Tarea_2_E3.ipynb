# %% [markdown]
# # Tarea 2, Ejercicio 3 - _Metodo de la secante_.
# $f(x) = 8xsen(x){e^{-x}}-1$, tomado en cuenta los valores $(x_0) = -0.3$ y $({x_{-1}}) = 0.5$

# %%
import numpy as np
import matplotlib.pyplot as plt

fx = lambda x: 8*x*np.sin(x)*np.exp(-x)-1
error_rel = lambda va, vn: (np.abs(va - vn)/np.abs(va))*100
xviejo = -0.3
xnuevo = 0.5

num_iteraciones = 5

for i in range(num_iteraciones):
  xi = round(xviejo-(fx(xviejo))*(xnuevo-xviejo)/(fx(xnuevo)-fx(xviejo)),4)
  er = round(error_rel(xi,xviejo),4)
  xnuevo = xviejo
  xviejo = xi
  print('..........................................................')
  print(f'i = {i+1} | xi = {xviejo} | x_0 = {xnuevo} | er = {er} %')

x = np.linspace(-5,5,100)
plt.plot(x,fx(x))
plt.plot(xi,fx(xi),'ro')
plt.grid()
plt.show()
# Out:
# ..........................................................
# i = 1 | xi = -0.1343 | x_0 = -0.3 | er = 123.3805 %
# ..........................................................
# i = 2 | xi = -0.3089 | x_0 = -0.1343 | er = 56.5231 %
# ..........................................................
# i = 3 | xi = -0.3042 | x_0 = -0.3089 | er = 1.545 %
# ..........................................................
# i = 4 | xi = -0.3058 | x_0 = -0.3042 | er = 0.5232 %
# ..........................................................
# i = 5 | xi = -0.3058 | x_0 = -0.3058 | er = 0.0 %
